# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
#from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + city # + "&appid=" + weather_api_key

requests.get(city_url).json()
# Out:
# {'coord': {'lon': -73.414, 'lat': 41.3712},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 52.32,
#   'feels_like': 51.44,
#   'temp_min': 49.55,
#   'temp_max': 55.36,
#   'pressure': 1011,
#   'humidity': 89},
#  'visibility': 9656,
#  'wind': {'speed': 1.01, 'deg': 303, 'gust': 4},
#  'rain': {'1h': 0.12},
#  'clouds': {'all': 100},
#  'dt': 1682221364,
#  'sys': {'type': 2,
#   'id': 2004826,
#   'country': 'US',
#   'sunrise': 1682157817,
#   'sunset': 1682206824},
#  'timezone': -14400,
#  'id': 5282297,
#  'name': 'Bethel',
#  'cod': 200}

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date =  city_weather["dt"] 

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind_speed,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tura
# Processing Record 2 of Set 1 | tolanaro
# Processing Record 3 of Set 1 | alice springs
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | ciudad bolivar
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | muratpasa
# City not found. Skipping...
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | papatowai
# Processing Record 12 of Set 1 | uturoa
# Processing Record 13 of Set 1 | kilbirnie
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | revda
# Processing Record 16 of Set 1 | vorgashor
# Processing Record 17 of Set 1 | laguna
# Processing Record 18 of Set 1 | barra do garcas
# Processing Record 19 of Set 1 | berezovyy
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | invercargill
# Processing Record 23 of Set 1 | port macquarie
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | yuzhno-kurilsk
# Processing Record 26 of Set 1 | kisesa
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | margaret river
# Processing Record 29 of Set 1 | puerto natales
# Processing Record 30 of Set 1 | tobruk
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | tralee
# Processing Record 33 of Set 1 | isafjordur
# Processing Record 34 of Set 1 | ciudad lazaro cardenas
# Processing Record 35 of Set 1 | bandar lampung
# Processing Record 36 of Set 1 | vennesla
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | mbandaka
# Processing Record 40 of Set 1 | susuman
# Processing Record 41 of Set 1 | ola
# Processing Record 42 of Set 1 | medicine hat
# Processing Record 43 of Set 1 | machico
# Processing Record 44 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 45 of Set 1 | port-aux-francais
# Processing Record 46 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | klyuchi
# Processing Record 49 of Set 1 | vorkuta
# Processing Record 50 of Set 1 | campina grande
# Processing Record 0 of Set 2 | masuguru
# Processing Record 1 of Set 2 | rock springs
# Processing Record 2 of Set 2 | carutapera
# Processing Record 3 of Set 2 | urangan
# Processing Record 4 of Set 2 | errachidia
# Processing Record 5 of Set 2 | north battleford
# Processing Record 6 of Set 2 | hadibu
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | aasiaat
# Processing Record 9 of Set 2 | qaqortoq
# Processing Record 10 of Set 2 | labytnangi
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | lata
# Processing Record 13 of Set 2 | edinburgh of the seven seas
# Processing Record 14 of Set 2 | sarina
# Processing Record 15 of Set 2 | awjilah
# Processing Record 16 of Set 2 | yanchep
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 19 of Set 2 | wailua homesteads
# Processing Record 20 of Set 2 | morondava
# Processing Record 21 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 2 | tyukhtet
# Processing Record 23 of Set 2 | oranjemund
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | fale old settlement
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | marbletown
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | mansa
# Processing Record 30 of Set 2 | nola
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | turpan
# Processing Record 33 of Set 2 | chinde
# Processing Record 34 of Set 2 | la passe
# Processing Record 35 of Set 2 | horta
# Processing Record 36 of Set 2 | zaysan
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | dongola
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | talara
# Processing Record 41 of Set 2 | itagui
# Processing Record 42 of Set 2 | tarko-sale
# Processing Record 43 of Set 2 | vernon
# Processing Record 44 of Set 2 | nyurba
# Processing Record 45 of Set 2 | bandarbeyla
# Processing Record 46 of Set 2 | laojunmiao
# Processing Record 47 of Set 2 | udachny
# Processing Record 48 of Set 2 | alto araguaia
# Processing Record 49 of Set 2 | keflavik
# Processing Record 0 of Set 3 | bathurst city centre
# City not found. Skipping...
# Processing Record 1 of Set 3 | tosno
# Processing Record 2 of Set 3 | lihue
# Processing Record 3 of Set 3 | tuy hoa
# Processing Record 4 of Set 3 | port mathurin
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | dolores
# Processing Record 7 of Set 3 | hammerfest
# Processing Record 8 of Set 3 | atafu village
# Processing Record 9 of Set 3 | thunder bay
# Processing Record 10 of Set 3 | west island
# Processing Record 11 of Set 3 | cockburn town
# Processing Record 12 of Set 3 | cambria
# Processing Record 13 of Set 3 | tossa de mar
# Processing Record 14 of Set 3 | bilibino
# Processing Record 15 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 3 | stutterheim
# Processing Record 17 of Set 3 | bealanana
# Processing Record 18 of Set 3 | paimio
# Processing Record 19 of Set 3 | island harbour
# Processing Record 20 of Set 3 | alliance
# Processing Record 21 of Set 3 | tazovsky
# Processing Record 22 of Set 3 | kyren
# Processing Record 23 of Set 3 | comodoro rivadavia
# Processing Record 24 of Set 3 | howrah
# Processing Record 25 of Set 3 | lieksa
# Processing Record 26 of Set 3 | sabang
# Processing Record 27 of Set 3 | ikungi
# Processing Record 28 of Set 3 | naze
# Processing Record 29 of Set 3 | constantia
# Processing Record 30 of Set 3 | i-n-salah
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | luganville
# Processing Record 34 of Set 3 | murghob
# Processing Record 35 of Set 3 | praia da vitoria
# Processing Record 36 of Set 3 | nemuro
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | narvik
# Processing Record 39 of Set 3 | svilengrad
# Processing Record 40 of Set 3 | kapuskasing
# Processing Record 41 of Set 3 | cold lake
# Processing Record 42 of Set 3 | lakatoro
# Processing Record 43 of Set 3 | kone
# Processing Record 44 of Set 3 | okhotsk
# Processing Record 45 of Set 3 | papao
# Processing Record 46 of Set 3 | hamilton
# Processing Record 47 of Set 3 | airdrie
# Processing Record 48 of Set 3 | badger
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 0 of Set 4 | ormara
# Processing Record 1 of Set 4 | tadine
# Processing Record 2 of Set 4 | qaisumah
# Processing Record 3 of Set 4 | puerto baquerizo moreno
# Processing Record 4 of Set 4 | sirnach
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | san antonio de pale
# Processing Record 7 of Set 4 | san luis de la loma
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | zarghun shahr
# Processing Record 10 of Set 4 | socorro
# Processing Record 11 of Set 4 | anadyr
# Processing Record 12 of Set 4 | sandpoint
# Processing Record 13 of Set 4 | sequeira
# Processing Record 14 of Set 4 | bro
# Processing Record 15 of Set 4 | kargasok
# Processing Record 16 of Set 4 | tosontsengel
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | vanimo
# Processing Record 19 of Set 4 | suncho corral
# Processing Record 20 of Set 4 | katabu
# Processing Record 21 of Set 4 | novaya igirma
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | teknaf
# Processing Record 24 of Set 4 | fisterra
# Processing Record 25 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 26 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 4 | turkestan
# Processing Record 28 of Set 4 | neryungri
# Processing Record 29 of Set 4 | yellowknife
# Processing Record 30 of Set 4 | christchurch
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | tidjikja
# Processing Record 33 of Set 4 | novo aripuana
# Processing Record 34 of Set 4 | georgetown
# Processing Record 35 of Set 4 | brokopondo
# Processing Record 36 of Set 4 | kununurra
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | walvis bay
# Processing Record 39 of Set 4 | happy valley-goose bay
# Processing Record 40 of Set 4 | daru
# Processing Record 41 of Set 4 | portland
# Processing Record 42 of Set 4 | kalajoki
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | grand baie
# Processing Record 45 of Set 4 | calatayud
# Processing Record 46 of Set 4 | mhangura
# Processing Record 47 of Set 4 | sisimiut
# Processing Record 48 of Set 4 | hasaki
# Processing Record 49 of Set 4 | maumere
# Processing Record 0 of Set 5 | whitehorse
# Processing Record 1 of Set 5 | cidreira
# Processing Record 2 of Set 5 | rio gallegos
# Processing Record 3 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 4 of Set 5 | hermanus
# Processing Record 5 of Set 5 | genhe
# Processing Record 6 of Set 5 | midvagur
# Processing Record 7 of Set 5 | moose jaw
# Processing Record 8 of Set 5 | stanley
# Processing Record 9 of Set 5 | ploudalmezeau
# Processing Record 10 of Set 5 | poyarkovo
# Processing Record 11 of Set 5 | marsh harbour
# Processing Record 12 of Set 5 | kargat
# Processing Record 13 of Set 5 | bushland beach
# City not found. Skipping...
# Processing Record 14 of Set 5 | meridian
# Processing Record 15 of Set 5 | indramayu
# Processing Record 16 of Set 5 | new norfolk
# Processing Record 17 of Set 5 | lazaro cardenas
# Processing Record 18 of Set 5 | bonthe
# Processing Record 19 of Set 5 | punta arenas
# Processing Record 20 of Set 5 | sao joao da barra
# Processing Record 21 of Set 5 | kittila
# Processing Record 22 of Set 5 | kailua-kona
# Processing Record 23 of Set 5 | borogontsy
# Processing Record 24 of Set 5 | kalemie
# Processing Record 25 of Set 5 | juegang
# Processing Record 26 of Set 5 | muisne
# Processing Record 27 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 5 | tanjung pandan
# Processing Record 29 of Set 5 | sunset hills
# Processing Record 30 of Set 5 | richards bay
# Processing Record 31 of Set 5 | tamanrasset
# Processing Record 32 of Set 5 | ponta delgada
# Processing Record 33 of Set 5 | ketchikan
# Processing Record 34 of Set 5 | live oak
# Processing Record 35 of Set 5 | hotan
# Processing Record 36 of Set 5 | nuuk
# Processing Record 37 of Set 5 | ishqoshim
# Processing Record 38 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 39 of Set 5 | singrauli
# Processing Record 40 of Set 5 | afaahiti
# Processing Record 41 of Set 5 | jingmen
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | mar del plata
# Processing Record 44 of Set 5 | baghdad
# Processing Record 45 of Set 5 | jayapura
# Processing Record 46 of Set 5 | piraquara
# Processing Record 47 of Set 5 | filingue
# Processing Record 48 of Set 5 | phatthalung
# Processing Record 49 of Set 5 | vadso
# Processing Record 0 of Set 6 | kavalerovo
# Processing Record 1 of Set 6 | parras de la fuente
# Processing Record 2 of Set 6 | tazacorte
# Processing Record 3 of Set 6 | nuzvid
# Processing Record 4 of Set 6 | edd
# Processing Record 5 of Set 6 | garibaldi
# Processing Record 6 of Set 6 | shingu
# Processing Record 7 of Set 6 | robore
# Processing Record 8 of Set 6 | mana
# Processing Record 9 of Set 6 | suixi
# Processing Record 10 of Set 6 | lompoc
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | panama city beach
# Processing Record 13 of Set 6 | eydhafushi
# Processing Record 14 of Set 6 | boa vista
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | enewetak
# Processing Record 17 of Set 6 | dryden
# Processing Record 18 of Set 6 | dali
# Processing Record 19 of Set 6 | kaihua
# Processing Record 20 of Set 6 | morden
# Processing Record 21 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 22 of Set 6 | moundou
# Processing Record 23 of Set 6 | berdigestyakh
# Processing Record 24 of Set 6 | padang
# Processing Record 25 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 26 of Set 6 | east london
# Processing Record 27 of Set 6 | puerto leguizamo
# Processing Record 28 of Set 6 | nay pyi taw
# Processing Record 29 of Set 6 | baruun-urt
# Processing Record 30 of Set 6 | mejit
# Processing Record 31 of Set 6 | pariaman
# Processing Record 32 of Set 6 | vanino
# Processing Record 33 of Set 6 | taboshar
# Processing Record 34 of Set 6 | tsiombe
# Processing Record 35 of Set 6 | boende
# Processing Record 36 of Set 6 | ust'-ilimsk
# Processing Record 37 of Set 6 | khorixas
# Processing Record 38 of Set 6 | kerikeri
# Processing Record 39 of Set 6 | cabedelo
# Processing Record 40 of Set 6 | manacapuru
# Processing Record 41 of Set 6 | nikolayevsk-on-amure
# Processing Record 42 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 43 of Set 6 | chonchi
# Processing Record 44 of Set 6 | butembo
# Processing Record 45 of Set 6 | abeche
# Processing Record 46 of Set 6 | gaspe
# Processing Record 47 of Set 6 | bejubang dua
# City not found. Skipping...
# Processing Record 48 of Set 6 | port alfred
# Processing Record 49 of Set 6 | ash shafa
# City not found. Skipping...
# Processing Record 0 of Set 7 | harlingen
# Processing Record 1 of Set 7 | alexandria
# Processing Record 2 of Set 7 | abalak
# Processing Record 3 of Set 7 | box elder
# Processing Record 4 of Set 7 | stephenville
# Processing Record 5 of Set 7 | bel ombre
# Processing Record 6 of Set 7 | flying fish cove
# Processing Record 7 of Set 7 | aykhal
# Processing Record 8 of Set 7 | puerto ayacucho
# Processing Record 9 of Set 7 | tommot
# Processing Record 10 of Set 7 | barakani
# Processing Record 11 of Set 7 | fedorovka
# Processing Record 12 of Set 7 | ntungamo
# Processing Record 13 of Set 7 | minden
# Processing Record 14 of Set 7 | pangody
# Processing Record 15 of Set 7 | popoli
# Processing Record 16 of Set 7 | el doncello
# Processing Record 17 of Set 7 | chagoda
# Processing Record 18 of Set 7 | ust-nera
# Processing Record 19 of Set 7 | korla
# Processing Record 20 of Set 7 | palikir - national government center
# Processing Record 21 of Set 7 | juneau
# Processing Record 22 of Set 7 | dhidhdhoo
# Processing Record 23 of Set 7 | tual
# Processing Record 24 of Set 7 | villa del totoral
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | leander
# Processing Record 27 of Set 7 | manay
# Processing Record 28 of Set 7 | el calafate
# Processing Record 29 of Set 7 | khirkiyan
# Processing Record 30 of Set 7 | kokopo
# Processing Record 31 of Set 7 | usinsk
# Processing Record 32 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 33 of Set 7 | kalachinsk
# Processing Record 34 of Set 7 | saint-augustin-de-desmaures
# Processing Record 35 of Set 7 | ghormach
# Processing Record 36 of Set 7 | yanbu
# Processing Record 37 of Set 7 | beidaihehaibin
# Processing Record 38 of Set 7 | vilyuchinsk
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | udayagiri
# Processing Record 41 of Set 7 | mount gambier
# Processing Record 42 of Set 7 | northam
# Processing Record 43 of Set 7 | jinka
# Processing Record 44 of Set 7 | hawaiian paradise park
# Processing Record 45 of Set 7 | hakui
# Processing Record 46 of Set 7 | maloye ganyushkino
# Processing Record 47 of Set 7 | beaufort west
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | fort bragg
# Processing Record 0 of Set 8 | nar'yan-mar
# Processing Record 1 of Set 8 | camocim
# Processing Record 2 of Set 8 | gorontalo
# Processing Record 3 of Set 8 | port lincoln
# Processing Record 4 of Set 8 | plesetsk
# Processing Record 5 of Set 8 | khandyga
# Processing Record 6 of Set 8 | la foa
# Processing Record 7 of Set 8 | salekhard
# Processing Record 8 of Set 8 | puerto deseado
# Processing Record 9 of Set 8 | chulakkurgan
# Processing Record 10 of Set 8 | saint croix
# Processing Record 11 of Set 8 | prince rupert
# Processing Record 12 of Set 8 | saint-philippe
# Processing Record 13 of Set 8 | sungai raya
# Processing Record 14 of Set 8 | igarka
# Processing Record 15 of Set 8 | vokhtoga
# Processing Record 16 of Set 8 | asubulaq
# Processing Record 17 of Set 8 | sosnovo-ozerskoye
# Processing Record 18 of Set 8 | dabakala
# Processing Record 19 of Set 8 | tselinnoye
# Processing Record 20 of Set 8 | yelizovo
# Processing Record 21 of Set 8 | tabou
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | macheng
# Processing Record 24 of Set 8 | pontal do parana
# Processing Record 25 of Set 8 | san patricio
# Processing Record 26 of Set 8 | zhalantun
# Processing Record 27 of Set 8 | vikhorevka
# Processing Record 28 of Set 8 | pikalevo
# Processing Record 29 of Set 8 | dudinka
# Processing Record 30 of Set 8 | katsuura
# Processing Record 31 of Set 8 | auki
# Processing Record 32 of Set 8 | kenora
# Processing Record 33 of Set 8 | bubaque
# Processing Record 34 of Set 8 | saipan
# Processing Record 35 of Set 8 | chui
# Processing Record 36 of Set 8 | kovdor
# Processing Record 37 of Set 8 | sao vicente
# Processing Record 38 of Set 8 | howard springs
# Processing Record 39 of Set 8 | zernograd
# Processing Record 40 of Set 8 | verkhnevilyuysk
# Processing Record 41 of Set 8 | wagar
# Processing Record 42 of Set 8 | tanout
# Processing Record 43 of Set 8 | queenstown
# Processing Record 44 of Set 8 | chimay
# Processing Record 45 of Set 8 | labrador city
# Processing Record 46 of Set 8 | shizunai-furukawacho
# Processing Record 47 of Set 8 | pisco
# Processing Record 48 of Set 8 | muroto-misakicho
# Processing Record 49 of Set 8 | weno
# Processing Record 0 of Set 9 | san rafael del yuma
# Processing Record 1 of Set 9 | kudat
# Processing Record 2 of Set 9 | an nuhud
# Processing Record 3 of Set 9 | anna regina
# Processing Record 4 of Set 9 | poronaysk
# Processing Record 5 of Set 9 | shetpe
# Processing Record 6 of Set 9 | nogliki
# Processing Record 7 of Set 9 | selfoss
# Processing Record 8 of Set 9 | caleta de carquin
# Processing Record 9 of Set 9 | remire-montjoly
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | benghazi
# Processing Record 12 of Set 9 | enid
# Processing Record 13 of Set 9 | nguigmi
# Processing Record 14 of Set 9 | la spezia
# Processing Record 15 of Set 9 | at taj
# Processing Record 16 of Set 9 | tingo maria
# Processing Record 17 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 9 | ilebo
# Processing Record 19 of Set 9 | kharan
# Processing Record 20 of Set 9 | cabagan
# Processing Record 21 of Set 9 | aldergrove
# Processing Record 22 of Set 9 | suva
# Processing Record 23 of Set 9 | kavieng
# Processing Record 24 of Set 9 | trondheim
# Processing Record 25 of Set 9 | iskateley
# Processing Record 26 of Set 9 | terbanggi besar
# Processing Record 27 of Set 9 | kolokani
# Processing Record 28 of Set 9 | santa elena de uairen
# Processing Record 29 of Set 9 | nova sintra
# Processing Record 30 of Set 9 | nantucket
# Processing Record 31 of Set 9 | sampit
# Processing Record 32 of Set 9 | kodiak
# Processing Record 33 of Set 9 | hami
# Processing Record 34 of Set 9 | primero de mayo
# Processing Record 35 of Set 9 | itaituba
# Processing Record 36 of Set 9 | utrik
# Processing Record 37 of Set 9 | monrovia
# Processing Record 38 of Set 9 | loushanguan
# Processing Record 39 of Set 9 | san-pedro
# Processing Record 40 of Set 9 | coquimbo
# Processing Record 41 of Set 9 | berdyansk
# Processing Record 42 of Set 9 | baise city
# Processing Record 43 of Set 9 | andergrove
# Processing Record 44 of Set 9 | broome
# Processing Record 45 of Set 9 | chibougamau
# Processing Record 46 of Set 9 | goynuk
# Processing Record 47 of Set 9 | nao me toque
# Processing Record 48 of Set 9 | yen vinh
# Processing Record 49 of Set 9 | merritt island
# Processing Record 0 of Set 10 | boquete
# Processing Record 1 of Set 10 | bardai
# Processing Record 2 of Set 10 | port douglas
# Processing Record 3 of Set 10 | preobrazheniye
# Processing Record 4 of Set 10 | gannan
# Processing Record 5 of Set 10 | charters towers
# Processing Record 6 of Set 10 | lagoa
# Processing Record 7 of Set 10 | turbat
# Processing Record 8 of Set 10 | khopoli
# Processing Record 9 of Set 10 | noshiro
# Processing Record 10 of Set 10 | dawesville
# Processing Record 11 of Set 10 | tchintabaraden
# Processing Record 12 of Set 10 | lukolela
# Processing Record 13 of Set 10 | rockingham
# Processing Record 14 of Set 10 | ryotsu-minato
# Processing Record 15 of Set 10 | antofagasta
# Processing Record 16 of Set 10 | zouerate
# Processing Record 17 of Set 10 | deir ez-zor
# Processing Record 18 of Set 10 | ad dabbah
# Processing Record 19 of Set 10 | fiambala
# Processing Record 20 of Set 10 | brandon
# Processing Record 21 of Set 10 | sogndal
# Processing Record 22 of Set 10 | greenville
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | agadez
# Processing Record 25 of Set 10 | khamis mushait
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | san ignacio
# Processing Record 28 of Set 10 | slave lake
# Processing Record 29 of Set 10 | taulaga
# Processing Record 30 of Set 10 | kisangani
# Processing Record 31 of Set 10 | kingston
# Processing Record 32 of Set 10 | covington
# Processing Record 33 of Set 10 | saskatoon
# Processing Record 34 of Set 10 | baker city
# Processing Record 35 of Set 10 | cam ranh
# Processing Record 36 of Set 10 | pitanga
# Processing Record 37 of Set 10 | monte alegre de minas
# Processing Record 38 of Set 10 | polyarnyye zori
# Processing Record 39 of Set 10 | kolonia
# Processing Record 40 of Set 10 | sukhothai
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | chulym
# Processing Record 43 of Set 10 | sejenane
# Processing Record 44 of Set 10 | paris
# Processing Record 45 of Set 10 | guarenas
# Processing Record 46 of Set 10 | sandnessjoen
# Processing Record 47 of Set 10 | pionerskiy
# Processing Record 48 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 49 of Set 10 | saiha
# Processing Record 0 of Set 11 | ilheus
# Processing Record 1 of Set 11 | saint-joseph
# Processing Record 2 of Set 11 | berezovo
# Processing Record 3 of Set 11 | sittwe
# Processing Record 4 of Set 11 | fang
# Processing Record 5 of Set 11 | al mindak
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | paracuru
# Processing Record 8 of Set 11 | calingasta
# Processing Record 9 of Set 11 | dingli
# Processing Record 10 of Set 11 | cimin
# Processing Record 11 of Set 11 | nehe
# Processing Record 12 of Set 11 | fuglafjordur
# Processing Record 13 of Set 11 | belabo
# Processing Record 14 of Set 11 | champua
# Processing Record 15 of Set 11 | sarakhs
# Processing Record 16 of Set 11 | mikhaylovskoye
# Processing Record 17 of Set 11 | khanty-mansiysk
# Processing Record 18 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 19 of Set 11 | bayanaul
# Processing Record 20 of Set 11 | anastacio
# Processing Record 21 of Set 11 | alamos
# Processing Record 22 of Set 11 | kindu
# Processing Record 23 of Set 11 | kachia
# Processing Record 24 of Set 11 | banda aceh
# Processing Record 25 of Set 11 | fada
# Processing Record 26 of Set 11 | hadsund
# Processing Record 27 of Set 11 | puerto armuelles
# Processing Record 28 of Set 11 | manavalakurichi
# Processing Record 29 of Set 11 | chegdomyn
# Processing Record 30 of Set 11 | ras gharib
# City not found. Skipping...
# Processing Record 31 of Set 11 | kloulklubed
# Processing Record 32 of Set 11 | kangding
# Processing Record 33 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 11 | brookings
# Processing Record 35 of Set 11 | bintulu
# Processing Record 36 of Set 11 | tippi
# Processing Record 37 of Set 11 | ta`u
# Processing Record 38 of Set 11 | huicheng
# Processing Record 39 of Set 11 | kudahuvadhoo
# Processing Record 40 of Set 11 | madugula
# Processing Record 41 of Set 11 | petauke
# Processing Record 42 of Set 11 | mtskheta
# Processing Record 43 of Set 11 | didim
# Processing Record 44 of Set 11 | umarkot
# Processing Record 45 of Set 11 | ozu
# Processing Record 46 of Set 11 | navojoa
# Processing Record 47 of Set 11 | kuanda
# Processing Record 48 of Set 11 | la ronge
# Processing Record 49 of Set 11 | gadzhiyevo
# Processing Record 0 of Set 12 | manggar
# Processing Record 1 of Set 12 | abnub
# Processing Record 2 of Set 12 | soure
# Processing Record 3 of Set 12 | west bay
# Processing Record 4 of Set 12 | korkuteli
# Processing Record 5 of Set 12 | astaneh-ye ashrafiyeh
# Processing Record 6 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 12 | igatpuri
# Processing Record 8 of Set 12 | al ghayzah
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | zliten
# Processing Record 11 of Set 12 | harjavalta
# Processing Record 12 of Set 12 | semenov
# Processing Record 13 of Set 12 | st. john's
# Processing Record 14 of Set 12 | parnu
# Processing Record 15 of Set 12 | fuerte olimpo
# Processing Record 16 of Set 12 | itambe
# Processing Record 17 of Set 12 | bontang
# Processing Record 18 of Set 12 | egilsstadir
# Processing Record 19 of Set 12 | qarah bagh
# Processing Record 20 of Set 12 | dangriga
# Processing Record 21 of Set 12 | plaquemine
# Processing Record 22 of Set 12 | ocean city
# Processing Record 23 of Set 12 | inirida
# Processing Record 24 of Set 12 | priargunsk
# Processing Record 25 of Set 12 | fray luis beltran
# Processing Record 26 of Set 12 | kourou
# Processing Record 27 of Set 12 | cidade velha
# Processing Record 28 of Set 12 | along
# Processing Record 29 of Set 12 | qulsary
# Processing Record 30 of Set 12 | bad frankenhausen
# Processing Record 31 of Set 12 | lospalos
# Processing Record 32 of Set 12 | umm kaddadah
# Processing Record 33 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 34 of Set 12 | martinsicuro
# Processing Record 35 of Set 12 | haiku-pauwela
# Processing Record 36 of Set 12 | marsabit
# Processing Record 37 of Set 12 | veraval
# Processing Record 38 of Set 12 | tshabong
# Processing Record 39 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 40 of Set 12 | dalandzadgad
# Processing Record 41 of Set 12 | ribeira brava
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) 

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s')
city_data_df['Date'] = city_data_df['Date'].dt.strftime('%Y-%m-%d')
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           tura  25.5198   90.2201     81.90        50         100
# 1       tolanaro -25.0319   46.9987     70.88        79           0
# 2  alice springs -23.7000  133.8833     78.35        27          34
# 3    olonkinbyen  70.9221   -8.7187     25.39        59           8
# 4      adamstown -25.0660 -130.1015     75.31        91         100
#
#    Wind Speed Country        Date
# 0        4.03      IN  2023-04-23
# 1        2.93      MG  2023-04-23
# 2       16.11      AU  2023-04-23
# 3       12.84      SJ  2023-04-23
# 4       12.95      PN  2023-04-23

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 tura  25.5198   90.2201     81.90        50         100
# 1             tolanaro -25.0319   46.9987     70.88        79           0
# 2        alice springs -23.7000  133.8833     78.35        27          34
# 3          olonkinbyen  70.9221   -8.7187     25.39        59           8
# 4            adamstown -25.0660 -130.1015     75.31        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.03      IN  2023-04-23
# 1              2.93      MG  2023-04-23
# 2             16.11      AU  2023-04-23
# 3             12.84      SJ  2023-04-23
# 4             12.95      PN  2023-04-23

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
lat_vs_temp = plt.scatter( city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="Black") 

title = f"City Latitude vs. Max Temperature ({city_data_df['Date'].min()})"
plt.title(title)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/Lat_vs_Temps_Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
lat_vs_humid = plt.scatter( city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="Black") 

title = f"City Latitude vs. Humidity ({city_data_df['Date'].min()})"

plt.title(title)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
# Save the figure
plt.savefig("../output_data/lat_vs_humid_Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
lat_vs_clouds = plt.scatter( city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="Black") 
 
title = f"City Latitude vs. Cloudiness ({city_data_df['Date'].min()})"
    
plt.title(title)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/lat_vs_clouds_Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
lat_vs_clouds = plt.scatter( city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="Black") 
 
title = f"City Latitude vs. Wind Speed ({city_data_df['Date'].min()})"
    
plt.title(title)
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("../output_data/lat_vs_windspeed_Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
city_data_df = city_data_df.rename(columns={"Max Temp": "Max Temp (F)", "Humidity": "Humidity (%)",
                                           "Cloudiness": "Cloudiness (%)", "Wind Speed": "Wind Speed (mph)"})
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp (F)  Humidity (%)  \
# City_ID
# 0                 tura  25.5198   90.2201         81.90            50
# 1             tolanaro -25.0319   46.9987         70.88            79
# 2        alice springs -23.7000  133.8833         78.35            27
# 3          olonkinbyen  70.9221   -8.7187         25.39            59
# 4            adamstown -25.0660 -130.1015         75.31            91
#
#          Cloudiness (%)  Wind Speed (mph) Country        Date
# City_ID
# 0                   100              4.03      IN  2023-04-23
# 1                     0              2.93      MG  2023-04-23
# 2                    34             16.11      AU  2023-04-23
# 3                     8             12.84      SJ  2023-04-23
# 4                   100             12.95      PN  2023-04-23

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy.stats import linregress

def plot_linear_regression(df, x_col, y_col):
    """
    Plots a scatter plot with a linear regression line for two columns in a dataframe.

    Parameters:
        df (pandas.DataFrame): The dataframe containing the data.
        x_col (str): The name of the column to use as the x-axis.
        y_col (str): The name of the column to use as the y-axis.
    """

    # Calculate linear regression parameters using linregress
    slope, intercept, rvalue, pvalue, stderr = linregress(df[x_col], df[y_col])

    # Create scatter plot with matplotlib
    plt.scatter(df[x_col], df[y_col])

    # Add regression line to scatter plot
    plt.plot(df[x_col], intercept + slope*df[x_col], 'r')

    # Set title with variable names
    title = f"{x_col.capitalize()} vs. {y_col.capitalize()} Linear Regression"
    plt.title(title)
    
    plt.xlabel(x_col)
    plt.ylabel(y_col)

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp (F)  Humidity (%)  \
# City_ID
# 0                  tura  25.5198  90.2201         81.90            50
# 3           olonkinbyen  70.9221  -8.7187         25.39            59
# 6        ciudad bolivar   8.1222 -63.5497         79.90            75
# 8                albany  42.6001 -73.9662         55.63            92
# 11            kilbirnie  55.7508  -4.6879         45.93            87
#
#          Cloudiness (%)  Wind Speed (mph) Country        Date
# City_ID
# 0                   100              4.03      IN  2023-04-23
# 3                     8             12.84      SJ  2023-04-23
# 6                   100              0.96      VE  2023-04-23
# 8                   100             11.39      US  2023-04-23
# 11                  100              1.01      GB  2023-04-23

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp (F)  Humidity (%)  \
# City_ID
# 1             tolanaro -25.0319   46.9987         70.88            79
# 2        alice springs -23.7000  133.8833         78.35            27
# 4            adamstown -25.0660 -130.1015         75.31            91
# 5            carnarvon -24.8667  113.6333         80.80            40
# 7        blackmans bay -43.0167  147.3167         62.74            50
#
#          Cloudiness (%)  Wind Speed (mph) Country        Date
# City_ID
# 1                     0              2.93      MG  2023-04-23
# 2                    34             16.11      AU  2023-04-23
# 4                   100             12.95      PN  2023-04-23
# 5                    96              6.71      AU  2023-04-23
# 7                    90              2.46      AU  2023-04-23

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df, 'Lat', 'Max Temp (F)')

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df, 'Lat', 'Max Temp (F)')

# %% [markdown]
# **Discussion about the linear relationship:** The linear regressions above show the max temperatures increasing closer to latitude 0, and max temperatures decreasing away from latitude 0 for the current datetime.  With the maximum temperatures clustered tightly to the regression line, there appears to be a strong linear relationship between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df, 'Lat', 'Humidity (%)')

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df, 'Lat', 'Humidity (%)')

# %% [markdown]
# **Discussion about the linear relationship:** The trend line for humidity was no more than 20% between the max latitudes and latitude 0.  However, the humidity data is widely dispersed from the regression line indicating a weak relationship between humidity and position of latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df, 'Lat', 'Cloudiness (%)')

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df, 'Lat', 'Cloudiness (%)')

# %% [markdown]
# **Discussion about the linear relationship:** We see in this linear regression model, a similar correlation between cloudiness and latitude, as was demonstrated between humidity and latitude.  The trend line for cloudiness was no more than 20% increase from the max latitudes and latitude 0. However, the cloud data is widely dispersed from the regression line indicating a weak relationship between cloudiness and position of latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df, 'Lat', 'Wind Speed (mph)')

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df, 'Lat', 'Wind Speed (mph)')

# %% [markdown]
# **Discussion about the linear relationship:** Trend lines for both the Northern and Southern hemispheres trend upward going away from latitude 0.
